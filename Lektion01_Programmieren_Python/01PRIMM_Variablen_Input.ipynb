# %% [markdown]
# # Lektion 1: Programmieren in Python
#
# Dieses Notebook folgt dem **PRIMM-Ansatz**: Vorhersagen (Predict), Ausführen (Run), Untersuchen (Investigate), Verändern (Modify), Erstellen (Make).
#
# Bitte arbeiten Sie **der Reihe nach** vor. Ihre schriftlichen Antworten halten Sie auf dem **Arbeitsblatt** fest, den Programmcode schreiben Sie hier im Notebook.

# %% [markdown]
# ## Predict – Vorhersagen
#
# Lesen Sie das folgende Programm, **ohne es auszuführen**.
#
# - Was glauben Sie, macht das Programm?
# - Welche Eingaben werden von Ihnen verlangt?
# - Welche Ausgaben erscheinen auf dem Bildschirm?
#
# Notieren Sie Ihre Vorhersage auf dem Arbeitsblatt.

# %%
# Starterprogramm Lektion 1
name = "Billy"
print("We want to know if you like programming!")
print()
print("Do you like programming " + name + "?")
answer = input()
print("Great! You said " + answer + "!")
print("Let's learn some Python today")

# %% [markdown]
# ## Run – Ausführen
#
# Führen Sie das Programm oben aus (Zelle anklicken, dann ▶ oder Umschalt+Eingabe).
#
# Vergleichen Sie das Ergebnis mit Ihrer Vorhersage und halten Sie den Abgleich auf dem Arbeitsblatt fest.

# %% [markdown]
# ## Investigate – Untersuchen
#
# Beantworten Sie die folgenden Fragen auf dem Arbeitsblatt. Sie dürfen dafür im Programm oben ausprobieren.
#
# 1. **Wie viele Variablen** kommen im Programm vor und **wofür** werden sie verwendet?
# 2. `print()` ist eine Funktion, die Text auf dem Bildschirm ausgibt. **Welche andere Funktion** kommt vor und was macht sie?
# 3. Wofür wird das Pluszeichen **`+`** in diesem Programm verwendet?
# 4. Was passiert, wenn Sie `print()` **ohne Inhalt** in den Klammern verwenden?

# %% [markdown]
# ## Modify – Verändern
#
# Führen Sie die folgenden Änderungen durch.
#
# 1. Ändern Sie das Programm so, dass **Ihr eigener Name** anstelle von `"Billy"` verwendet wird.
# 2. Ändern Sie das Programm so, dass Sie die **Antwort direkt in derselben Zeile** wie die Frage eingeben können. *Hinweis:* Sie können `input("Ihre Frage ... ")` benutzen.
# 3. Ändern Sie das Programm so, dass **zu Beginn** nach dem **Namen** der Benutzerin oder des Benutzers gefragt wird.

# %%
# Aufgabe 1 bis 3: Kopieren Sie das Starterprogramm in diese Zelle und passen Sie es an.

# %% [markdown]
# ## Make – Erstellen
#
# Schreiben Sie ein **neues Programm**, das drei Fragen stellt und jeweils eine passende Rückmeldung gibt:
#
# - Wie heißen Sie?
# - Was hatten Sie zum Frühstück?
# - Was ist Ihre Lieblingsfarbe?
#
# So könnte die Ausgabe aussehen:
#
# ```
# Wie heißen Sie? Greta
# Hallo Greta!
# Was hatten Sie zum Frühstück, Greta? Müsli
# Müsli klingt gut!
# ...
# ```

# %%
# Schreiben Sie Ihr neues Programm hier.

# %% [markdown]
# ### Erweiterung
#
# Fragen Sie zusätzlich nach dem **Alter** und geben Sie anschließend aus, wie alt die Person **am nächsten Geburtstag** sein wird.
#
# *Hinweis:* Verwenden Sie `int(input("Wie alt sind Sie? "))` und bei der Ausgabe `str(...)` zur Umwandlung in Text.
#
# So könnte die Ausgabe aussehen:
#
# ```
# Wie heißen Sie? Greta
# Wie alt sind Sie, Greta? 13
# Danke – dann werden Sie am nächsten Geburtstag 14.
# ```

# %%
# Implementieren Sie die Erweiterung hier.

# %% [markdown]
# ---
#
# Zum Abschluss: Füllen Sie die Tabelle **Schlüsselbegriffe** auf dem Arbeitsblatt aus.
