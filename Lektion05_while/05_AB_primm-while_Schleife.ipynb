# %% [markdown]
# # Lektion 5: while-Schleife
#
# *Dieses Arbeitsblatt bearbeiten Sie in einem Jupyter Notebook. Orientieren Sie sich am PRIMM-Ansatz (Predict, Run, Investigate, Modify, Make).*

# %% [markdown]
# ![](img/image1.png)

# %% [markdown]
# ## Aufgabe 1: Beantworten Sie diese Fragen

# %%
# Übertragen Sie das Programm aus dem Bild oberhalb dieser Aufgabe in diese Zelle
# und führen Sie es anschließend aus.

# %% [markdown]
# - Hat das Programm so funktioniert, wie Sie es vorhergesagt haben?

# %% [markdown]
# - Was waren die Unterschiede?

# %% [markdown]
# ## Aufgaben

# %% [markdown]
# Verwenden Sie das Starterprogramm als Hilfe für diese Übungen, indem Sie es kopieren und für jede Übung ändern.

# %% [markdown]
# Schreiben Sie ein Programm, das mithilfe einer while-Schleife hundert Mal „Heute ist Montag“ ausgibt. Vergleichen Sie dies mit der Methode, die wir letzte Woche mit einer for-Schleife verwendet haben.

# %% [markdown]
# ![](img/image2.png)

# %%
# Schreiben Sie ein Programm, das mithilfe einer while-Schleife hundert Mal „Heute ist Montag“ ausgibt. Vergleichen Sie dies mit der Methode, die wir letzte Woche mit einer for-Sc...

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Schreiben Sie ein Programm, das den Benutzer nach dem Namen des letzten Sturms fragt und so lange fragt, bis er den Namen „Doris” eingibt. Rechts finden Sie einen Code für die Eingabeanweisung, damit Sie loslegen können

# %% [markdown]
# ![](img/image4.png)

# %%
# Schreiben Sie ein Programm, das den Benutzer nach dem Namen des letzten Sturms fragt und so lange fragt, bis er den Namen „Doris” eingibt. Rechts finden Sie einen Code für die E...

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Schreiben Sie ein Programm, das den Benutzer nach einer Zahl fragt, bis er 99 eingibt. Wenn er 99 eingibt, stoppt das Programm.

# %% [markdown]
# ![](img/image5.png)

# %%
# Schreiben Sie ein Programm, das den Benutzer nach einer Zahl fragt, bis er 99 eingibt. Wenn er 99 eingibt, stoppt das Programm.

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Schreiben Sie eine Funktion bored() mit einer while-Schleife, die die unten angezeigte Ausgabe hat.
#
# Beginnen Sie mit

# %% [markdown]
# ![](img/image6.png)

# %% [markdown]
# ![](img/image7.png)

# %%
# Schreiben Sie eine Funktion bored() mit einer while-Schleife, die die rechts angezeigte Ausgabe hat. Beginnen Sie mit
# def bored()
# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Schreiben Sie ein Programm, das die Zahlen von 1 bis 10 ausgibt. Sie können dies mit einer while-Schleife oder einer for-Schleife tun. Versuchen Sie es auf beide Arten.

# %% [markdown]
# ![](img/image8.png)

# %%
# Schreiben Sie ein Programm, das die Zahlen von 1 bis 10 ausgibt. Sie können dies mit einer while-Schleife oder einer for-Schleife tun. Versuchen Sie es auf beide Arten.

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Ändern Sie nun Ihr Programm aus (5) so, dass es die Zahlen von 10 bis 1 ausgibt.

# %% [markdown]
# ![](img/image9.png)

# %%
# Ändern Sie nun Ihr Programm aus (5) so, dass es die Zahlen von 10 bis 1 ausgibt.

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Das Programm auf der rechten Seite fordert den Benutzer zur Eingabe eines Passworts auf. Wann wird das Programm beendet? Führen Sie es aus und sehen Sie selbst.
#
#
#
# Fügen Sie als Nächstes einen Code hinzu, der zählt, wie viele Versuche der Benutzer hatte, und geben Sie dies am Ende des Programms aus.
#
#
#
# Wie könnten Sie dieses Programm noch verbessern?

# %% [markdown]
# ![](img/image10.png)

# %% [markdown]
# Verbessern Sie das Quiz, das Sie geschrieben haben, indem Sie eine while-Schleife hinzufügen. Stellen Sie die Frage so lange, bis der Benutzer sie richtig beantwortet.

# %% [markdown]
# ![](img/image11.png)

# %%
# Verbessern Sie das Quiz, das Sie geschrieben haben, indem Sie eine while-Schleife hinzufügen. Stellen Sie die Frage so lange, bis der Benutzer sie richtig beantwortet.

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# # Schlüsselbegriffe – Lektion 5 Schleifen

# %% [markdown]
# | Begriff | Bedeutung | Wie man es in Python macht |
# | --- | --- | --- |
# | Iteration | Eine Schleife. Es gibt zwei Arten von Schleifen: for-Schleifen (mit einer festgelegten Anzahl von Wiederholungen) und bedingte Schleifen oder while-Schleifen. |  |

# %% [markdown]
# ![](img/image12.png)

# %% [markdown]
# While-Schleifen sind bedingunsabhängig

# %% [markdown]
# Der zweite Schleifentyp, den es neben der for-Schleife in Python gibt, ist die while-Schleife. Während bei der for-Schleife ein fest vorgegebener Bereich durchlaufen wird, hängt die while-Schleife von einer Bedingung ab.

# %% [markdown]
# **Allgemeine Form einer `while`-Schleife:**
#
# ```python
# while <Bedingung>:
# 	<Anweisung 1>
# 	<Anweisung 2>
# …
# ```

# %% [markdown]
# ![](img/image13.png)

# %% [markdown]
# Vergleich einer for-Schleife mit einer while-Schleife (am Beispiel Hochzählen 1 bis 10)

# %% [markdown]
# **Vergleich: `for`-Schleife und `while`-Schleife (Zahlen 1 bis 10)**

# %%
# for-Schleife
for zahl in range(1, 11):
    print(zahl)

# while-Schleife
zahl = 1
while zahl < 11:
    print(zahl)
    zahl += 1

# %% [markdown]
# Immer wenn ein fest definierter Bereich durchlaufen werden soll, ist die for-Schleife der while-Schleife vorzuziehen.

# %% [markdown]
# ## Mehrwert der while-Schleife

# %% [markdown]
# Wann brauchen wir eine while-Schleife?
#
#
#
# z.B. wenn der Nutzer flexibel die Anzahl der Schleifendurchläufe festlegen möchte….

# %% [markdown]
# **Beispiel:**
#
# ```python
# zahl=0
# fortfahren="j"
#
# while fortfahren=="j":
#     zahl+=1
#     print(zahl)
#     fortfahren=input("Geben Sie j an, wenn Sie fortfahren mögen ")
#
# print(f"Du hast bis {zahl} gezählt")
# ```

# %% [markdown]
# ## Vorsicht ENDLOSSCHLEIFE

# %% [markdown]
# Sie haben voller Freude ein neues Programm geschrieben, drücken auf ausführen und warten..und warten…und warten! Es passiert nichts, Ihr Programm scheint aber mit etwas beschäftigt zu sein. Wenn das passiert, sind Sie in einer Endlosschleife gefangen. Eine Endlosschleife ist eine Schleife, die ständig wiederholt wird, ohne jemals zu Ende zu kommen.  Beispiel:

# %% [markdown]
# zahl=1

# %% [markdown]
# while zahl<11:

# %% [markdown]
# print(zahl)

# %% [markdown]
# #zahl+=1: (Hochzählen vergessen – Die Bedingung bleibt stets true)

# %% [markdown]
# Endlosschleifen sind logische Fehler und müssen behoben werden, damit das Programm tut, was es soll.

# %% [markdown]
# ## Übungsaufgaben – Schleifen (for- und while-Schleifen)

# %% [markdown]
# 1 Implementieren Sie auf Grundlage des nachfolgenden Programmablaufplans ein Programm in Python.

# %%
# Implementieren Sie auf Grundlage des nachfolgenden Programmablaufplans ein Programm in Python.

# Schreiben Sie Ihren Python-Code hier.
pass

# %% [markdown]
# Realisieren Sie anschließend einen entsprechenden Algorithmus mit der for-Schleife.

# %% [markdown]
# ![](img/image14.png)

# %% [markdown]
# 2 Eine Schleife soll genauso oft durchlaufen werden, wie der Nutzer zu Beginn des Programms eingibt. Bei jedem Durchlauf soll ausgegeben werden: Dies ist der x. Schleifendurchlauf.

# %% [markdown]
# Lösen Sie die Problemstellung sowohl mit der while- als auch mit der for-Schleife.

# %% [markdown]
# 3 Schreiben Sie ein Programm, bei dem alle Teiler einer beliebigen Zahl ermittelt werden. Realisieren Sie folgende Eingabe bzw. Ausgabe:

# %%
# Schreiben Sie ein Programm, bei dem alle Teiler einer beliebigen Zahl ermittelt werden. Realisieren Sie folgende Eingabe bzw. Ausgabe:

# Schreiben Sie Ihren Python-Code hier.

# %% [markdown]
# Bitte geben Sie die Zahl ein, für die Sie die Teiler wissen möchten: 6Die Teiler von 6 sind: 1236 Möchten Sie eine weitere Zahl eingeben? (ja/nein):

# %% [markdown]
# 4 Programmieren Sie bitte folgendes Lernspiel: Fragen Sie den Benutzer eine Frage aus einem aktuellen Wissensfeld (z.B. Wie nennt man eine Handlungsvorschrift zur Lösung eines Problems in der Informatik?). Falls der Nutzer eine falsche Antwort gibt, soll er gefragt werden, ob er nochmal eine weitere Antwort geben möchte. Programmieren Sie das Spiel so, dass der Nutzer bei einer korrekten Lösung die Antwort „Richtig. Du hast x Versuche gebraucht.“ erhält. Kann der Nutzer keine korrekte Antwort liefern oder hat er mehr als 3 Lösungsversuche gebraucht, erhält er eine Rückmeldung über die korrekte Antwort.

# %%
# Programmieren Sie bitte folgendes Lernspiel: Fragen Sie den Benutzer eine Frage aus einem aktuellen Wissensfeld (z.B. Wie nennt man eine Handlungsvorschrift zur Lösung eines Pro...

# Schreiben Sie Ihren Python-Code hier.
pass

# %% [markdown]
# **5** Ihr Kalorienbedarf liegt bei circa 2200 kcal. Sie beschließen, eine Diät zu machen und für 3 Tage weniger zu essen. Das Programm fragt Sie, wie viele Mahlzeiten Sie an einem Tag zu sich nehmen. Dann fragt es für jeden Tag und für jede Mahlzeit nach den Kalorien, die Sie zu sich genommen haben. Am Ende zieht das Programm eine Gesamtbilanz. 7000 kcal entsprechen einem Kilogramm Körperfett. Das Programm sagt Ihnen, wie viele kg Fett Sie mit dieser Aktion losgeworden sind.
